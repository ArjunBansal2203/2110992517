# %%
#Task 2
#1

import matplotlib.pyplot as plt
data = []
for i in range(5):
    value = float(input("Enter value {}: ".format(i+1)))
    data.append(value)
print(data)
plt.figure(figsize=(10, 10))
mylabels=["Apples", "Bananas", "Cherries", "Pear","Mango"]
plt.pie(data, labels=mylabels, autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()

plt.figure(figsize=(10, 10))
plt.bar(mylabels, data)
plt.title('Bar Chart')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()
# Out:
# Enter value 1:  3
# Enter value 2:  4
# Enter value 3:  5
# Enter value 4:  6
# Enter value 5:  7
# [3.0, 4.0, 5.0, 6.0, 7.0]

# %%
#2

import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('sales2.csv')

# a) Data Analysis with Pandas by displaying top and bottom 10 rows
print("Top 10 Rows:")
print(df.head(10))
print("\nBottom 10 Rows:")
print(df.tail(10))

# b) Calculate total sales by adding the data values mentioned in Sales attribute in the file
total_sales = df['Sales'].sum()
print("\nTotal Sales: ", total_sales)

# c) Find the mean Sales
mean_sales = df['Sales'].mean()
print("\nMean Sales: ", mean_sales)


# d) Group the Sales by Category
grouped = df.groupby('Category')['Sales'].sum()
print("\nSales by Category:")
print(grouped)

# e) Plot the Sales Product-wise
df.plot(kind='bar', x='Product', y='Sales')

# f) Mention xlabel, ylabel, and title to the plot
plt.xlabel('Product')
plt.ylabel('Sales')
plt.title('Sales Product-wise')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 5
#       3 import matplotlib.pyplot as plt
#       4 import pandas as pd
# ----> 5 df = pd.read_csv('sales2.csv')
#       7 # a) Data Analysis with Pandas by displaying top and bottom 10 rows
#       8 print("Top 10 Rows:")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sales2.csv'

# %%
#3

import numpy as np
array = np.array([[1, 2], [3, 4]])

# a) Insert column in the 2D array
array = np.insert(array, 1, [[5], [6]], axis=1)
print("Array After Inserting Column:")
print(array)

# b) Difference between array1[:,0] and array2[:,[0]]
array1 = np.array([[1, 2], [3, 4]])
array2 = np.array([[1, 2], [3, 4]])
print("\narray1[:,0]:", array1[:,0])
print("array2[:,[0]]:", array2[:,[0]])

# c) Use argmax() function to get axis of maximum element of the array
array = np.array([[1, 2], [3, 4]])
axis = np.argmax(array)
print("\nAxis of Maximum Element: ", axis)

# d) Showcase the difference between argsort() and sort()
array = np.array([3, 1, 4, 2])
indices = np.argsort(array)
sorted_array = array[indices]
print("\nSorted Array:")
print(sorted_array)

# e) Difference between np.mean() and np.average() in NumPy
array = np.array([1, 2, 3, 4])
mean = np.mean(array)
average = np.average(array)
print("\nMean: ", mean)
print("Average: ", average)

# f) Count the frequency of a given positive value appearing in the NumPy array
array = np.array([1, 2, -2, 3, 1, 1])
value = 2
count = np.count_nonzero(array == value)
print("\nFrequency of ", value, ":", count)

# g) Inserting * between characters of all elements in a NumPy array
array = np.array(['au', 'de', 'qy'])
with_stars = np.array(['*'.join(item) for item in array])
print("Inserting * between characters of all elements")
print(with_stars,'\n')
# Out:
# Array After Inserting Column:
# [[1 5 6 2]
#  [3 5 6 4]]
#
# array1[:,0]: [1 3]
# array2[:,[0]]: [[1]
#  [3]]
#
# Axis of Maximum Element:  3
#
# Sorted Array:
# [1 2 3 4]
#
# Mean:  2.5
# Average:  2.5
#
# Frequency of  2 : 1
# Inserting * between characters of all elements
# ['a*u' 'd*e' 'q*y']

# %%
#Task 1

import pandas as pd
file = pd.read_csv("Covid-19.csv")

random_sample = file.sample(10)
file_filled = file.fillna(0)

numeric_columns = file_filled.select_dtypes(include=[int, float]).columns

population_mean = file_filled[numeric_columns].mean()
sample_mean = random_sample[numeric_columns].mean()

if population_mean.equals(sample_mean):
    message = "The sample mean is equal to the population mean."
else:
    message = "The sample mean is not equal to the population mean."

print("\n1. Selecting random sample from the file")
print("\nPrinting Random 10 rows\n")
print(random_sample)

print("\n2. Comparing population mean and sample mean")
print("Population Mean is:")
print(population_mean)
print("\nSample Mean is:")

print(sample_mean)
print("\n3. Displaying result whether sample mean represent the data or not")
print("\nComparison Result:")
print(message)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 import pandas as pd
# ----> 2 file = pd.read_csv("Covid-19.csv")
#       4 random_sample = file.sample(10)
#       5 file_filled = file.fillna(0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Covid-19.csv'
